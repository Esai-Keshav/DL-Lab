# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt

from tensorflow.keras.datasets import cifar10
from tensorflow.keras import Sequential, layers

# %%
train_ds, test_ds = cifar10.load_data()
train_ds = tf.data.Dataset.from_tensor_slices(train_ds)
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170498071/170498071 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
def show_images(images):
    n = len(images)
    for i , image in enumerate(images):
        plt.subplot(1, n, i+1)
        plt.imshow(image)
        plt.axis("off")

    plt.show()

# %%
IMG_SIZE = 64
resize_and_rescale = Sequential([
    layers.Resizing(IMG_SIZE, IMG_SIZE),
    layers.Rescaling(1/255.)
])

# %%
resized_images = train_ds.take(4).map(lambda x, y: resize_and_rescale(x))

show_images(resized_images)

# %%
data_augumentation  = Sequential([
    layers.RandomFlip(),
    layers.RandomRotation(factor=0.2),
    layers.RandomContrast(factor=(0.2, 0.9))
])

# %%
aug_images = resized_images.map(data_augumentation)
show_images(aug_images)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.063897].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.2948232].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.005074978..1.0925331].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.1226048].

# %%
AUTOTUNE = tf.data.AUTOTUNE

# %%
def prepare(ds):
    return ds.map(lambda x, y: (resize_and_rescale(x), y), num_parallel_calls=AUTOTUNE) \
        .map(lambda x, y:( data_augumentation(x), y), num_parallel_calls=AUTOTUNE) \
        .prefetch(buffer_size =AUTOTUNE)

# %%
prepared_ds = prepare(train_ds).take(4)
show_images(prepared_ds.map(lambda x, y: x))
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.3590935].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.3705093].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [0.0..1.2282994].

# %%
image, label = next(iter(train_ds))

# %%
show_images([
    tf.image.flip_left_right(image),
    tf.image.flip_up_down(image),
    tf.image.adjust_brightness(image, -0.2),
    tf.image.adjust_contrast(image, 2),
    tf.image.adjust_saturation(image, 2)
])

# %%
show_images([
    tf.image.stateless_random_contrast(image, lower=0.1, upper=5, seed=(i, 0))
    for i in range(1, 6)
])

# %%
show_images([
    tf.image.stateless_random_brightness(image, max_delta=0.8, seed=(i, 0))
    for i in range(1, 6)
])
